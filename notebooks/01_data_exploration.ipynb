# %% [markdown]
# # Data Exploration
# Modular notebook using `src` helpers.

# %%
from src.reproducibility import load_yaml, project_root
from src.data import load_dataset, write_data_quality_outputs
from src.visualization import plot_eda

root = project_root()
config = load_yaml(root / 'configs' / 'experiment.yaml')
df, manifest = load_dataset(config)
write_data_quality_outputs(df, root / 'results')
plot_eda(df, root / 'figures', config['random_seed'])
df.head()
