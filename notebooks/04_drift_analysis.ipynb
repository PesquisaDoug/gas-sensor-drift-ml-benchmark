# %% [markdown]
# # Drift Analysis
# Generate drift comparisons from benchmark outputs.

# %%
import pandas as pd
from src.drift import classification_drift_table, regression_drift_table

classification = pd.read_csv('results/classification_metrics.csv')
regression = pd.read_csv('results/regression_metrics.csv')
classification_drift_table(classification), regression_drift_table(regression)
