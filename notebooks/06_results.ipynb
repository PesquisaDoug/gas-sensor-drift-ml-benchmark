# %% [markdown]
# # Results
# Generate paper-ready aggregate results.

# %%
# !python -m scripts.generate_results --config configs/experiment.yaml --profile quick
